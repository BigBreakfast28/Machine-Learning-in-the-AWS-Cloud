# %%
import matplotlib as plt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
input_file = 'C:/Users/deanc/Documents/Datasets/Titanic/train.csv'
df_titanic = pd.read_csv(input_file)

# %%
df_titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_survived = df_titanic[df_titanic['Survived']==1]
df_not_survived = df_titanic[df_titanic['Survived']==0]

counts = df_titanic['Embarked'].value_counts(dropna=True)
values = counts.index

embarked_survived = df_survived['Embarked'].value_counts(dropna=True).reindex(counts.index,fill_value=0)
embarked_not_survived = df_not_survived['Embarked'].value_counts(dropna=True).reindex(counts.index,fill_value=0)

embarked_survived_percentage = embarked_survived/counts * 100
embarked_not_survived_percentage = embarked_not_survived/counts * 100

x_positions = np.arange(len(values))

figure1, ax = plt.subplots(figsize=(7,7))
ax.set_xticks(x_positions,values)
ax.set_xlabel('% Embarked Ports Survival')
ax.set_ylabel('Count')
ax.grid()
figure1.suptitle('% Embarked Ports Survival Rates')
ax.bar(x_positions, embarked_survived_percentage, label='Survived', color='#003300')
ax.bar(x_positions, embarked_not_survived_percentage, bottom=embarked_survived_percentage, label='Not Survived', color='#660066')

plt.legend()

# %%
df_survived = df_titanic[df_titanic['Survived']==1]
df_not_survived = df_titanic[df_titanic['Survived']==0]

counts = df_titanic['Embarked'].value_counts(dropna=True)
values = counts.index

embarked_survived = df_survived['Embarked'].value_counts(dropna=True).reindex(counts.index, fill_value=0)
embarked_not_survived = df_survived['Embarked'].value_counts(dropna=True).reindex(counts.index,fill_value=0)

x_positions = np.arange(len(values))
bar_width = 0.35

figure2, ax = plt.subplots(figsize=(9,9))
ax.grid()
ax.set_xlabel('Embarked Ports')
ax.set_ylabel('Count')
ax.set_xticks(x_positions, values)
figure2.suptitle('Figure 2 - Embakred Ports Survival Rates')
ax.bar(x_positions, embarked_survived, bar_width, label='Survived', color='#006600')
ax.bar(x_positions+bar_width, embarked_not_survived, bar_width, label='Not Survived', color='#993399')

plt.legend()

# %%
df_survived = df_titanic[df_titanic['Survived']==1]
df_not_survived = df_titanic[df_titanic['Survived']==0]

counts = df_titanic['Embarked'].value_counts(dropna=True)
values = counts.index

embarked_survived = df_survived['Embarked'].value_counts(dropna=True).reindex(counts.index,fill_value=0)
embarked_not_survived = df_not_survived['Embarked'].value_counts(dropna=True).reindex(counts.index,fill_value=0)

embarked_survived_percentage = embarked_survived/counts * 100
embarked_not_survived_percentage = embarked_not_survived/counts * 100

x_positions = np.arange(len(values))
bar_width = 0.35

figure3, ax = plt.subplots(figsize=(7,7))
ax.grid()
ax.set_xlabel('% Embarked Port Survivors')
ax.set_ylabel('Count')
ax.set_xticks(x_positions,values)
figure3.suptitle('Figure 3 - % Embarked Port Survivors')
ax.bar(x_positions, embarked_survived_percentage, bar_width, label='Survived', color='#336600')
ax.bar(x_positions+bar_width, embarked_not_survived_percentage, bar_width, label='Not Survived', color='#9900cc')

plt.legend()

# %%
df_survived = df_titanic[df_titanic['Survived']==1]
df_not_survived = df_titanic[df_titanic['Survived']==0]

counts = df_titanic['Embarked'].value_counts(dropna=True)
values = counts.index

embarked_survived = df_survived['Embarked'].value_counts(dropna=True).reindex(counts.index,fill_value=0)
embarked_not_survived = df_not_survived['Embarked'].value_counts(dropna=True).reindex(counts.index, fill_value=0)

embarked_survived_percentage = embarked_survived/counts * 100
embarked_not_survived_percentage = embarked_not_survived/counts * 100

x_positions = np.arange(len(values))

figure4, ax = plt.subplots(figsize=(7,7))
ax.grid()
ax.set_xlabel('% Embarked Port Survivors')
ax.set_ylabel('Count')
figure4.suptitle('Figure 4 - % Embarked Port Survivors')
ax.bar(x_positions, embarked_survived_percentage, label='Survived', color='#003366')
ax.bar(x_positions, embarked_not_survived_percentage, bottom= embarked_survived_percentage, label='Not Survived', color='#993333')

plt.legend()

# %%
df_survived = df_titanic[df_titanic['Survived']==1]
df_not_survived = df_titanic[df_titanic['Survived']==0]

counts = df_titanic['Embarked'].value_counts(dropna=True)
values = counts.index

embarked_survived = df_survived['Embarked'].value_counts(dropna=True).reindex(counts.index,fill_value=0)
embarked_not_survived = df_not_survived['Embarked'].value_counts(dropna=True).reindex(counts.index, fill_value=0)

embarked_survived_percentage = embarked_survived/counts * 100
embarked_not_survived_percentage = embarked_not_survived/counts * 100

x_positions = np.arange(len(values))

figure4, ax = plt.subplots(figsize=(7,7))
ax.grid()
ax.set_xlabel('% Embarked Port Survivors')
ax.set_ylabel('Count')
figure4.suptitle('Figure 4 - Embarked Port Survivors')
ax.bar(x_positions, embarked_survived, label='Survived', color='#003366')
ax.bar(x_positions, embarked_not_survived, bottom=embarked_survived, label='Not Survived', color='#993333')

plt.legend()

# %%
df_survived = df_titanic[df_titanic['Survived']==1]
df_not_survived = df_titanic[df_titanic['Survived']==0]

counts = df_titanic['Embarked'].value_counts(dropna=True)
values=counts.index

embarked_survived = df_survived['Embarked'].value_counts(dropna=True)
embarked_not_survived = df_not_survived['Embarked'].value_counts(dropna=True)

embarked_survived_percentage = embarked_survived/counts * 100
embarked_not_survived_percentage = embarked_not_survived/counts * 100

df=pd.concat([embarked_survived_percentage, embarked_not_survived_percentage], axis=1)

df.plot.bar(stacked=True, label='Survived', color=['#99ff66','#ff66cc'])
plt.suptitle('Figure 5 - % Survivors Stacked Bar Chart')
plt.legend()

# %%
#Another try at the pie chart
figure6 = plt.subplots(figsize=(7,7))

values = df_titanic['Embarked'].dropna().unique()
embarked = df_titanic['Embarked'].value_counts(dropna=True)

embarked_total = counts.values.sum()

embarked_percentage = embarked/embarked_total * 100

embarked_percentage.values

plt.pie(embarked_percentage.values, shadow=True, labels=values, autopct='%1.2f%%', startangle=30)
# Out:
# ([<matplotlib.patches.Wedge at 0x15840006ad0>,
# ...
#  [Text(-1.0362226256409734, 0.3691106475160628, 'S'),
#   Text(0.8988944788810567, -0.6340258006084246, 'C'),
#   Text(1.0653963840958267, 0.2737344420337675, 'Q')],
#  [Text(-0.5652123412587127, 0.20133308046330697, '72.44%'),
#   Text(0.4903060793896672, -0.34583225487732244, '18.90%'),
#   Text(0.5811253004159054, 0.14930969565478228, '8.66%')])

# %%
figure7 = plt.subplots(figsize=(7,7))

values = df_titanic['Pclass'].dropna().unique()
pclass = df_titanic['Pclass'].value_counts(dropna=True)

pclass_total = pclass.values.sum()

pclass_percentage = pclass/pclass_total * 100

pclass_percentage.values

plt.pie(pclass_percentage.values, labels=values, shadow=True, startangle=90, autopct='%1.2f%%')

figure8 = plt.subplots(figsize=(7,7))
df_titanic = df_titanic['Embarked'].value_counts(dropna=True).plot.pie()

# %%
figure8 = plt.subplots(figsize=(7,7))

values = df_titanic['Sex'].dropna().unique()
sex = df_titanic['Sex'].value_counts(dropna=True)

sex_total = sex.values.sum()

sex_percentage = sex/sex_total * 100

sex_percentage.values 

plt.pie(sex_percentage.values, labels=values, autopct='%1.2f%%', shadow=True, startangle=90)

figure9 = plt.subplots(figsize=(7,7))
sex_pandas = df_titanic['Sex'].value_counts(dropna=True).plot.pie()

# %%
figure9 = plt.subplots(figsize=(7,7))

values = df_titanic['Embarked'].dropna().unique()
embarked = df_titanic['Embarked'].value_counts(dropna=True)

embarked_total = embarked.values.sum()

embarked_percentage = embarked/embarked_total * 100

embarked_percentage.values

plt.pie(embarked_percentage.values, labels=values, autopct='%1.2f%%', shadow=True, startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x206f49e3250>,
# ...
#  [Text(-0.8377704896039081, -0.7128398184366725, 'S'),
#   Text(0.9985295659561383, 0.46145282089445105, 'C'),
#   Text(0.2956369278692323, 1.059527633844461, 'Q')],
#  [Text(-0.4569657216021316, -0.38882171914727587, '72.44%'),
#   Text(0.5446524905215299, 0.2517015386697005, '18.90%'),
#   Text(0.1612565061104903, 0.5779241639151605, '8.66%')])

# %%
embarked = df_titanic['Embarked'].value_counts(dropna=True).plot.pie()

# %%
s_df = df_titanic[df_titanic['Embarked']=='S']
q_df = df_titanic[df_titanic['Embarked']=='Q']
c_df = df_titanic[df_titanic['Embarked']=='C']

wedge_labels = ['Survived', 'Not Survived']

s_survived = s_df[s_df['Survived']==1].Embarked.count()
s_embarked_total = s_df['Embarked'].count()
s_not_survived = s_embarked_total - s_survived
s_survived_percentage = s_survived/s_embarked_total
s_not_survived_percentage = s_not_survived/s_embarked_total
s_wedge_group = [s_survived_percentage, s_not_survived_percentage]
print(q_not_survived)

q_survived = q_df[q_df['Survived']==1].Embarked.count()
q_embarked_total = q_df['Embarked'].count()
q_not_survived = q_embarked_total - q_survived
q_survived_percentage = q_survived/q_embarked_total
q_not_survived_percentage = q_not_survived/q_embarked_total
q_wedge_group = [q_survived_percentage, q_not_survived_percentage]

c_survived = c_df[c_df['Survived']==1].Embarked.count()
c_embarked_total = c_df['Embarked'].count()
c_not_survived = c_embarked_total - c_survived
c_survived_percentage = c_survived/c_embarked_total
c_not_survived_percentage = c_not_survived/c_embarked_total
c_wedge_group= [c_survived_percentage, c_not_survived_percentage]

figure10, ax = plt.subplots(1,3, figsize=(15,10))
figure10.suptitle('Figure 10 - Survived Pie Chart')

ax[0].set_title('Southampton')
ax[0].pie(s_wedge_group, labels=wedge_labels, autopct='%1.1f%%', shadow=True,startangle=90, colors=['#660066','#cc99ff'])

ax[1].set_title('Queenstown')
ax[1].pie(q_wedge_group, labels=wedge_labels, autopct='%1.1f%%', shadow=True,startangle=90, colors=['#996633','#00ffff'])

ax[2].set_title('Cherbourg')
ax[2].pie(c_wedge_group, labels=wedge_labels, autopct='%1.1f%%', shadow=True,startangle=90, colors=['#9933ff','#99ff33'])
# Out:
# 47
# ([<matplotlib.patches.Wedge at 0x18217619f90>,
# ...
#  [Text(-1.0844580916318263, -0.18425701477625675, 'Survived'),
#   Text(1.0844580755235618, 0.18425710958259722, 'Not Survived')],
#  [Text(-0.5915225954355415, -0.10050382624159458, '55.4%'),
#   Text(0.5915225866492154, 0.10050387795414392, '44.6%')])

# %%
df_survived = df_titanic[df_titanic['Survived']==1]
df_not_survived = df_titanic[df_titanic['Survived']==0]

counts = df_titanic['Pclass'].value_counts(dropna=True)
values = counts.index

pclass_survived = df_survived['Pclass'].value_counts(dropna=True).reindex(counts.index,fill_value=0)
pclass_not_survived = df_not_survived['Pclass'].value_counts(dropna=True).reindex(counts.index,fill_value=0)

pclass_survived_percentage = pclass_survived/counts * 100
pclass_not_survived_percentage = pclass_not_survived/counts * 100

pclass_survived_percentage.name = 'Survived'
pclass_not_survived_percentage.name = 'Not Survived'
df = pd.concat([pclass_survived_percentage,pclass_not_survived_percentage], axis=1)

chatgpt
# Out:
# array([<Axes: ylabel='3'>, <Axes: ylabel='1'>, <Axes: ylabel='2'>],
#       dtype=object)

# %%
pclass3_df = df_titanic[df_titanic['Pclass']==3]
pclass2_df = df_titanic[df_titanic['Pclass']==2]
pclass1_df = df_titanic[df_titanic['Pclass']==1]

wedge_label = ['Survived', 'Not Survived']

pclass3_survived = pclass3_df[pclass3_df['Survived']==1].Pclass.count()
pclass3_total = pclass3_df['Pclass'].count()
pclass3_not_survived = pclass3_total - pclass3_survived
pclass3_survived_percentage = pclass3_survived/pclass3_total * 100
pclass3_not_survived_percentage = pclass3_not_survived/pclass3_total * 100
pclass3_wedge_group = [pclass3_survived_percentage,pclass3_not_survived_percentage]

pclass2_survived = pclass2_df[pclass2_df['Survived']==1].Pclass.count()
pclass2_total = pclass2_df['Pclass'].count()
pclass2_not_survived = pclass2_total - pclass2_survived
pclass2_survived_percentage = pclass2_survived/pclass2_total * 100
pclass2_not_survived_percentage = pclass2_not_survived/pclass2_total * 100
pclass2_wedge_group = [pclass2_survived_percentage,pclass2_not_survived_percentage]

pclass1_survived = pclass1_df[pclass1_df['Survived']==1].Pclass.count()
pclass1_total = pclass1_df['Pclass'].count()
pclass1_not_survived = pclass1_total - pclass1_survived
pclass1_survived_percentage = pclass1_survived/pclass1_total * 100
pclass1_not_survived_percentage = pclass1_not_survived/pclass1_total * 100
pclass1_wedge_group = [pclass1_survived_percentage,pclass1_not_survived_percentage]

fig, ax = plt.subplots(1,3,figsize=(16,6))
fig.suptitle('Figure ? - Survival Rate for Passenger Class')

ax[0].set_title('Passenger Class 3')
ax[0].pie(pclass3_wedge_group, labels=wedge_label, autopct='%1.2f%%', shadow=True, startangle=90)

ax[1].set_title('Passenger Class 2')
ax[1].pie(pclass2_wedge_group, labels=wedge_label, autopct='%1.2f%%', shadow=True, startangle=90)

ax[2].set_title('Passenger Class 1')
ax[2].pie(pclass1_wedge_group, labels=wedge_label, autopct='%1.2f%%', shadow=True, startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x1b674b3df90>,
# ...
#  [Text(-1.0100376803126887, -0.435687829011281, 'Survived'),
#   Text(1.010037746099709, 0.43568767649982937, 'Not Survived')],
#  [Text(-0.550929643806921, -0.23764790673342598, '62.96%'),
#   Text(0.5509296796907502, 0.23764782354536146, '37.04%')])

# %%
df_survived = df_titanic[df_titanic['Survived']==1]
df_not_survived = df_titanic[df_titanic['Survived']==0]

counts = df_titanic['Pclass'].value_counts(dropna=True)
values = counts.index

pclass_survived = df_survived['Pclass'].value_counts(dropna=True).reindex(counts.index,fill_value=0)
pclass_not_survived = df_not_survived['Pclass'].value_counts(dropna=True).reindex(counts.index,fill_value=0)

pclass_survived_percentage = pclass_survived/counts * 100
pclass_not_survived_percentage = pclass_not_survived/counts * 100

pclass_survived_percentage.name = 'Survived'
pclass_not_survived_percentage.name = 'Not Survived'

df = pd.concat([pclass_survived_percentage,pclass_not_survived_percentage], axis=1)
df.T.plot.pie(sharex=True, subplots=True, figsize=(16,5))
# Out:
# array([<Axes: ylabel='3'>, <Axes: ylabel='1'>, <Axes: ylabel='2'>],
#       dtype=object)

# %%
df_survived = df_titanic[df_titanic['Survived']==1]
df_not_survived = df_titanic[df_titanic['Survived']==0]

counts = df_titanic['Sex'].value_counts(dropna=True)
values = counts.index

sex_survived = df_survived['Sex'].value_counts(dropna=True).reindex(counts.index,fill_value=0)
sex_not_survived = df_not_survived['Sex'].value_counts(dropna=True).reindex(counts.index,fill_value=0)

sex_survived_percentage = sex_survived/counts * 100
sex_not_survived_percentage = sex_not_survived/counts * 100

bar_width = 0.35
x_positions = np.arange(len(values))

fig, ax = plt.subplots(figsize=(5,5))
ax.grid()
ax.set_xlabel('% Male & Female Survived')
ax.set_ylabel('Count')
ax.set_xticks(x_positions,values)
ax.bar(x_positions, sex_survived_percentage, bar_width, label='Survived', color='#0033cc')
ax.bar(x_positions+bar_width,sex_not_survived_percentage, bar_width, label='Not Survived', color='#ff3399')
plt.legend()

# %%
#boxplot
df_survived = df_titanic[df_titanic['Survived']==1].dropna()
df_not_survived = df_titanic[df_titanic['Survived']==0].dropna()

fig, ax = plt.subplots(figsize=(5,5))
fare_boxplot = plt.boxplot([df_survived['Fare'], df_not_survived['Fare']],tick_labels=['Survived','Not Survived'])

# %%
df_titanic.boxplot(column='Age', by='Survived', figsize=(5,5),grid=True)
# Out:
# <Axes: title={'center': 'Age'}, xlabel='Survived'>

# %%
from sklearn import datasets
iris_dataset = datasets.load_iris()
df_iris = pd.DataFrame(iris_dataset.data, columns=iris_dataset.feature_names)
df_iris.head()


# 1. Get number of columns
# 2. Create subplot grid
# 3. Loop through rows
# 4. Loop through columns
# 5. Plot scatter
# 6. Hide ticks
# 7. Show edge labels
"""
def generate_scatter_matrix(df_input, size_h, size_w):
    num_ponts, num_attributes = df_input.shape

    #fig, ax = plt.subplots(num_attributes, num_attributes, figsize=(size_w,size_h))

    #column_name = df_input.columns.names

    #for x in range(num_attributes):
        #for y in range(num_attributes):
        #ax = axes[x,y]

        #ax.scatter(df_input.iloc[:,x],df_input.iloc[:,y])
    axes[x,y] = ax[x,y].plt.scatter() #incorrect
    ax[x,y] = df_input.iloc[:,x] #incorrect - right track
    ax[x,y] = df_input.iloc[:,y] #incorrect - right track

    ax[x,y].yaxis_set_visible(False)#good
    ax[x,y].xaxis_set_visible(False)#good

    if y == 0: #good
        #1 ax.set_ticks_position('left')
        #2 ax.set_visible(True)
        #3set_ylabel(column_name[x])
        #4 There's not a fouth category

    if y == num_attributes -1: #good
        #1 ax.yaxis_set_ticks_position('right')
        #2 ax.set_ylabel_visible(True)

    if x == 0: #good
        #1 ax.xaxis_set_ticks_position('top')
        #2 ax.xaxis_set_visible(True)
        #3 There's not a third 
        #4 There's not a fourth

    if x == num_attributes -1: #good
        #1 ax.set_ticks_position('bottom')
        #2 ax.xaxis_set_visible(True)
        #3 ax.xaxis_set_label(column_names[y])

return plt.scatter()
"""
# Out:
# "\ndef generate_scatter_matrix(df_input, size_h, size_w):\n    num_ponts, num_attributes = df_input.shape\n\n    #fig, ax = plt.subplots(num_attributes, num_attributes, figsize=(size_w,size_h))\n\n    #column_name = df_input.columns.names\n\n    #for x in range(num_attributes):\n        #for y in range(num_attributes):\n        #ax = axes[x,y]\n\n        #ax.scatter(df_input.iloc[:,x],df_input.iloc[:,y])\n    axes[x,y] = ax[x,y].plt.scatter() #incorrect\n    ax[x,y] = df_input.iloc[:,x] #incorrect - right track\n    ax[x,y] = df_input.iloc[:,y] #incorrect - right track\n\n    ax[x,y].yaxis_set_visible(False)#good\n    ax[x,y].xaxis_set_visible(False)#good\n\n    if y == 0: #good\n        #1 ax.set_ticks_position('left')\n        #2 ax.set_visible(True)\n        #3set_ylabel(column_name[x])\n        #4 There's not a fouth category\n\n    if y == num_attributes -1: #good\n        #1 ax.yaxis_set_ticks_position('right')\n        #2 ax.set_ylabel_visible(True)\n\n    if x == 0: #good\n  
# ...

# %%
def getmy_scatter_matrix(df_input, size_h, size_w):
    num_points, num_attributes = df_input.shape

    fig,axes = plt.subplots(num_attributes,num_attributes, figsize=(size_w,size_h))

    column_names = df_input.columns.values

    for x in range(num_attributes):
        for y in range(num_attributes):
            ax = axes[x,y]
            
            ax.scatter(df_input.iloc[:,x],df_input.iloc[:,y])

            if y == 0:
                ax.yaxis.set_ticks_position('left')
                ax.yaxis.set_visible(True)
                ax.set_ylabel(column_names[x])

            if y == num_attributes-1:
                ax.yaxis.set_ticks_position('right')
                ax.yaxis.set_visible(True)

            if x == 0:
                ax.xaxis.set_ticks_position('top')
                ax.xaxis.set_visible(True)

            if x == num_attributes-1:
                ax.xaxis.set_ticks_position('bottom')
                ax.xaxis.set_visible(True)
                ax.set_xlabel(column_names[y])

    return fig,axes
getmy_scatter_matrix(df_iris, 20,20)
# Out:
# (<Figure size 2000x2000 with 16 Axes>,
#  array([[<Axes: ylabel='sepal length (cm)'>, <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: ylabel='sepal width (cm)'>, <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: ylabel='petal length (cm)'>, <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: xlabel='sepal length (cm)', ylabel='petal width (cm)'>,
#          <Axes: xlabel='sepal width (cm)'>,
#          <Axes: xlabel='petal length (cm)'>,
#          <Axes: xlabel='petal width (cm)'>]], dtype=object))

# %%
def scatter_matrix(df_input, size_w, size_h):
    num_points, num_attributes = df_input.shape

    column_names = df_input.columns.values

    fig, axes = plt.subplots(num_attributes, num_attributes, figsize=(size_w,size_h))

    for x in range(num_attributes):
        for y in range(num_attributes):
            ax = axes[x,y]

            ax.scatter(df_input.iloc[:,x], df_input.iloc[:,y])

            if y == 0:
                ax.yaxis.set_ticks_position('left')
                ax.yaxis.set_visible(True)
                ax.set_ylabel(column_names[x])

            if y == num_attributes -1:
                ax.yaxis.set_ticks_position('right')
                ax.yaxis.set_visible(True)

            if x == 0:
                ax.xaxis.set_ticks_position('top')
                ax.xaxis.set_visible(True)

            if x == num_attributes -1:
                ax.xaxis.set_ticks_position('bottom')
                ax.xaxis.set_visible(True)
                ax.set_xlabel(column_names[y])

    return fig, axes

# %%
scatter_matrix(df_iris, 20,20)
# Out:
# (<Figure size 2000x2000 with 16 Axes>,
#  array([[<Axes: ylabel='sepal length (cm)'>, <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: ylabel='sepal width (cm)'>, <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: ylabel='petal length (cm)'>, <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: xlabel='sepal length (cm)', ylabel='petal width (cm)'>,
#          <Axes: xlabel='sepal width (cm)'>,
#          <Axes: xlabel='petal length (cm)'>,
#          <Axes: xlabel='petal width (cm)'>]], dtype=object))

# %%
df_survived = df_titanic[df_titanic['Survived']==1]
df_not_survived = df_titanic[df_titanic['Survived']==0]

counts = df_titanic['Embarked'].value_counts(dropna=True)
values = counts.index

embarked_survived = df_survived['Embarked'].value_counts(dropna=True).reindex(counts.index,fill_value=0)
embarked_not_survived = df_not_survived['Embarked'].value_counts(dropna=True).reindex(counts.index,fill_value=0)

embarked_survived_percentage = embarked_survived/counts * 100
embarked_not_survived_percentage = embarked_not_survived/counts * 100

bar_width = 0.35
x_positions = np.arange(len(values))

fig, ax = plt.subplots(1,3,figsize=(15,6))
ax[0].grid()
ax[0].set_xticks(x_positions,values)
ax[0].set_ylabel('Count')
ax[0].bar(x_positions, embarked_survived, bar_width, label='Survived', color='#339966')
ax[0].bar(x_positions+bar_width, embarked_not_survived, bar_width, label='Not Survived', color='#ffff00')


ax[1].grid()
ax[1].set_xticks(x_positions,values)
ax[1].set_ylabel('Count')
ax[1].bar(x_positions,embarked_survived_percentage,bar_width, label='Survived', color='#0000ff')
ax[1].bar(x_positions+bar_width, embarked_not_survived_percentage, bar_width, label='Not Survived', color='#ff3399')

ax[2].grid()
ax[2].set_xticks(x_positions,values)
ax[2].set_ylabel('Count')
ax[2].bar(x_positions,embarked_survived_percentage, label='Survived', color='#0099cc')
ax[2].bar(x_positions, embarked_not_survived_percentage, bottom=embarked_survived_percentage, label='Not Survived', color='#ff0000')

plt.legend()

# %%
df_survived = df_titanic[df_titanic['Survived']==1]
df_not_survived = df_titanic[df_titanic['Survived']==0]
embarked_total = df_titanic['Embarked'].value_counts(dropna=True)

wedge_labels = ['Survived', 'Not Survived']

s_total = df_titanic[df_titanic['Embarked']=='S'].Embarked.count()
s_survived = df_survived[df_survived['Embarked']=='S'].Embarked.count()
s_not_survived = s_total - s_survived 
s_survived_percentage = s_survived/s_total * 100
s_not_survived_percentage = s_not_survived/s_total * 100
s_wedge_group = [s_survived_percentage,s_not_survived_percentage]

c_total = df_titanic[df_titanic['Embarked']=='C'].Embarked.count()
c_survived = df_survived[df_survived['Embarked']=='C'].Embarked.count()
c_not_survived = c_total - c_survived 
c_survived_percentage = c_survived/c_total * 100
c_not_survived_percentage = c_not_survived/s_total * 100
c_wedge_group = [c_survived_percentage,c_not_survived_percentage]

q_total = df_titanic[df_titanic['Embarked']=='Q'].Embarked.count()
q_survived = df_survived[df_survived['Embarked']=='Q'].Embarked.count()
q_not_survived = q_total - q_survived 
q_survived_percentage = q_survived/q_total * 100
q_not_survived_percentage = q_not_survived/q_total * 100
q_wedge_group = [q_survived_percentage,q_not_survived_percentage]

fig, ax = plt.subplots(1,3, figsize=(15,10))

ax[0].pie(s_wedge_groups, labels=wedge_labels, autopct='%1.2f%%', startangle=90, colors=['#3333ff','#9933ff'])
ax[0].set_title('Southampton')

ax[1].pie(c_wedge_groups, labels=wedge_labels, autopct='%1.2f%%', startangle=90,colors=['#009933','#ff0000'])
ax[1].set_title('Cherbourg')

ax[2].pie(q_wedge_groups, labels=wedge_labels, autopct='%1.2f%%', startangle=90,colors=['#996633','#0033cc'])
ax[2].set_title('Queenstown')
# Out:
# Text(0.5, 1.0, 'Queenstown')

# %%
def get_matrix(df_input, size_w, size_h):
    num_points, num_attributes = df_input.shape

    fig, axes = plt.subplots(num_attributes,num_attributes, figsize=(size_w,size_h))

    column_names = df_input.columns.values

    for x in range(num_attributes):
        for y in range(num_attributes):
            ax = axes[x,y]
            ax.scatter(df_input.iloc[:,x],df_input.iloc[:,y])

            if y == 0:
                ax.yaxis.set_ticks_position('left')
                ax.yaxis.set_visible(True)
                ax.set_ylabel(column_names[x])

            if y == num_attributes-1:
                ax.yaxis.set_ticks_position('right')
                ax.yaxis.set_visible(True)

            if x == 0:
                ax.xaxis.set_ticks_position('top')
                ax.xaxis.set_visible(True)

            if x == num_attributes-1:
                ax.xaxis.set_ticks_position('bottom')
                ax.xaxis.set_visible(True)
                ax.set_xlabel(column_names[y])

    return fig, axes

# %%
from sklearn import datasets
iris_dataset = datasets.load_iris()
df_iris = pd.DataFrame(iris_dataset.data,columns=iris_dataset.feature_names)

get_matrix(df_iris,20,20)
# Out:
# (<Figure size 2000x2000 with 16 Axes>,
#  array([[<Axes: ylabel='sepal length (cm)'>, <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: ylabel='sepal width (cm)'>, <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: ylabel='petal length (cm)'>, <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: xlabel='sepal length (cm)', ylabel='petal width (cm)'>,
#          <Axes: xlabel='sepal width (cm)'>,
#          <Axes: xlabel='petal length (cm)'>,
#          <Axes: xlabel='petal width (cm)'>]], dtype=object))
